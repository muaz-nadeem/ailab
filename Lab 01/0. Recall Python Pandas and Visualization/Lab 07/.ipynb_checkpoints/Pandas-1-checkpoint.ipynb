# %% [markdown]
# ## Table of Content
#
# 1. **[Pandas](#pandas)**
#
#    <img align="center" src="https://habrastorage.org/files/10c/15f/f3d/10c15ff3dcb14abdbabdac53fed6d825.jpg"  width=50% />
#
#
# 2. **[Data Structures](#structures)**
#
# 3. **[Pandas Series](#series)**
#     - 3.1 - [Creating a Series](#creatingS)
#     - 3.2 - [Manipulating Series](#manipulatingS)
#
# 4. **[Pandas Dataframes](#dataframes)**
#     - 4.1 - [Creating Dataframes](#creatingDF)
#     - Dataframe Methods
#     - 4.2 - [Manipulating Dataframes](#manipulatingDF)
#
# 5. **[Merge Dataframe](#reading_data)**
#
# 6. **[Groupby Method](#reading_data)**

# %% [markdown]
# <a id="pandas"> </a>
# ## 1. Pandas
# #### Introduction to Pandas

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> Pandas contain data structures and data manipulation tools designed for data cleaning and analysis.
# <br><br>
#                         While Pandas adopt many coding idioms from Numpy, the biggest difference is that Pandas are designed for working with tabular or heterogeneous data. Numpy, by contrast, is best suited for working with homogeneous numerical array data.<br><br>
#                          The name Pandas is derived from the term “panel data”, an econometrics term for multidimensional structured data sets.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **How to install pandas?**<br>
# 1. You can use-<br>
# `!pip install pandas`<br>
# 2. You can import it as-<br>
# import pandas as pd

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ssc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ssc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    - -------------------------------------- 0.5/11.0 MB 82.2 kB/s eta 0:02:08
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    -- ------------------------------------- 0.8/11.0 MB 48.4 kB/s eta 0:03:31
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    --- ------------------------------------ 1.0/11.0 MB 47.5 kB/s eta 0:03:30
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ---- ----------------------------------- 1.3/11.0 MB 51.5 kB/s eta 0:03:09
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ----- ---------------------------------- 1.6/11.0 MB 58.7 kB/s eta 0:02:41
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------ --------------------------------- 1.8/11.0 MB 58.7 kB/s eta 0:02:37
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    ------- -------------------------------- 2.1/11.0 MB 56.6 kB/s eta 0:02:38
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    -------- ------------------------------- 2.4/11.0 MB 68.0 kB/s eta 0:02:08
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    --------- ------------------------------ 2.6/11.0 MB 67.2 kB/s eta 0:02:05
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ---------- ----------------------------- 2.9/11.0 MB 70.2 kB/s eta 0:01:56
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ----------- ---------------------------- 3.1/11.0 MB 73.5 kB/s eta 0:01:47
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------ --------------------------- 3.4/11.0 MB 65.3 kB/s eta 0:01:57
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    ------------- -------------------------- 3.7/11.0 MB 63.9 kB/s eta 0:01:55
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    -------------- ------------------------- 3.9/11.0 MB 64.0 kB/s eta 0:01:51
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    --------------- ------------------------ 4.2/11.0 MB 58.5 kB/s eta 0:01:57
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ---------------- ----------------------- 4.5/11.0 MB 53.3 kB/s eta 0:02:03
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ----------------- ---------------------- 4.7/11.0 MB 48.2 kB/s eta 0:02:11
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------ --------------------- 5.0/11.0 MB 49.4 kB/s eta 0:02:02
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    ------------------- -------------------- 5.2/11.0 MB 49.5 kB/s eta 0:01:57
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.5/11.0 MB 53.3 kB/s eta 0:01:44
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    -------------------- ------------------- 5.8/11.0 MB 55.9 kB/s eta 0:01:34
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    --------------------- ------------------ 6.0/11.0 MB 62.3 kB/s eta 0:01:20
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ---------------------- ----------------- 6.3/11.0 MB 62.4 kB/s eta 0:01:16
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ----------------------- ---------------- 6.6/11.0 MB 62.3 kB/s eta 0:01:12
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------ --------------- 6.8/11.0 MB 64.9 kB/s eta 0:01:05
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    ------------------------- -------------- 7.1/11.0 MB 62.2 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    -------------------------- ------------- 7.3/11.0 MB 58.6 kB/s eta 0:01:03
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
#    --------------------------- ------------ 7.6/11.0 MB 57.9 kB/s eta 0:00:59
# ...
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ----------------------------------- ---- 11.3/12.8 MB 47.5 kB/s eta 0:00:32
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.5/12.8 MB 39.0 kB/s eta 0:00:33
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------ --- 11.8/12.8 MB 40.1 kB/s eta 0:00:25
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    ------------------------------------- -- 12.1/12.8 MB 38.4 kB/s eta 0:00:20
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    -------------------------------------- - 12.3/12.8 MB 37.6 kB/s eta 0:00:13
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------  12.6/12.8 MB 22.8 kB/s eta 0:00:09
#    ---------------------------------------- 12.8/12.8 MB 24.5 kB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.4 pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\SSC\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# <a id="structures"> </a>
# ## 2. Data Structures
# #### Introduction to Data Structures

# %% [markdown]
# Pandas has two data structures as follows:<br>
# 1. A Series is 1-dimensional labeled array that can hold data of any type (integer, string, boolean, float, python objects, and so on). It’s axis labels are collectively called an index.<br>
# 2. A DataFrame is 2-dimensional labeled data structure with columns. It supports multiple datatypes.

# %% [markdown]
# <a id="series"> </a>
# ## 3. Pandas Series
# #### Introduction to Pandas Series and Creating Series

# %% [markdown]
# Pandas Series is a one-dimensional labeled array capable of holding any data type. However, a series is a sequence of homogeneous data types, similar to an array, or column in a table.<br><br>
#                         It will assign a labeled index to each item in the Series. By default, each item will receive an index label from 0 to N, where N is the length of the Series minus one.

# %% [markdown]
# <a id="creatingS"> </a>
# ### 3.1 Creating a Series

# %% [markdown]
# **1. To create a numeric series**

# %%
# create a numeric series
numbers = range(1,100,5)
pd.Series(numbers)
# Out:
# 0      1
# 1      6
# 2     11
# 3     16
# 4     21
# 5     26
# 6     31
# 7     36
# 8     41
# 9     46
# 10    51
# 11    56
# 12    61
# 13    66
# 14    71
# 15    76
# 16    81
# 17    86
# 18    91
# 19    96
# dtype: int64

# %% [markdown]
# The output also gives the data type of the series as `int64`
#
# And note that by default, each item will receive an index label from 0 to N, where N is the length of the Series minus one.

# %%
# create a Series with an arbitrary list
s = pd.Series([345, 'London', 34.5, -34.45, 'Happy Birthday'])
s
# Out:
# 0               345
# 1            London
# 2              34.5
# 3            -34.45
# 4    Happy Birthday
# dtype: object

# %%
marks = [60, 89, 74, 86]

subject = ["Maths", "Science", "English" , "Social Science"]

pd.Series(marks,index=subject)
# Out:
# Maths             60
# Science           89
# English           74
# Social Science    86
# dtype: int64

# %%
# create with dictionary
data = {'Maths': 60, 'Science': 89, 'English': 76, 'Social Science': 86}

pd.Series(data)
# Out:
# Maths             60
# Science           89
# English           76
# Social Science    86
# dtype: int64

# %%
# with missing values
subjects = ["Maths", "Science", "English","Art and Craft" , "Social Science"]

marks_series = pd.Series(data, index = subjects)

print(marks_series)
# Out:
# Maths             60.0
# Science           89.0
# English           76.0
# Art and Craft      NaN
# Social Science    86.0
# dtype: float64

# %% [markdown]
# <a id="manipulatingS"> </a>
# ### 3.2 Manipulating Series
# #### Manipulating series

# %% [markdown]
# ######  check null value

# %%
#  check null value
marks_series.isnull().sum()
# Out:
# 1

# %%
marks_series.notnull()
# Out:
# Maths              True
# Science            True
# English            True
# Art and Craft     False
# Social Science     True
# dtype: bool

# %% [markdown]
# **To know the subjects in which marks score is more than 75**

# %%
marks_series[marks_series > 75]
# Out:
# Science           89.0
# English           76.0
# Social Science    86.0
# dtype: float64

# %% [markdown]
# **To assign 68 marks to 'Art and Craft'**

# %%
marks_series
# Out:
# Maths             60.0
# Science           89.0
# English           76.0
# Art and Craft      NaN
# Social Science    86.0
# dtype: float64

# %%
marks_series["Art and Craft"] = 68
marks_series
# Out:
# Maths             60.0
# Science           89.0
# English           76.0
# Art and Craft     68.0
# Social Science    86.0
# dtype: float64

# %%
mar

# %%
marks_series
# Out:
# Maths             60.0
# Science           89.0
# English           76.0
# Art and Craft     68.0
# Social Science    86.0
# dtype: float64

# %%
marks_series[marks_series<70] = 65
marks_series
# Out:
# Maths             65.0
# Science           89.0
# English           76.0
# Art and Craft     65.0
# Social Science    86.0
# dtype: float64

# %%
# check math marks is?
marks_series.Maths == 73
# Out:
# False

# %%
# or you may use

marks_series["Maths"] == 73
# Out:
# False

# %% [markdown]
# **Sorting a numeric series**

# %%
# create a pandas series
import numpy as np
values = pd.Series([23, 45, np.nan, 41, 23, 34, 55, np.nan, 34, 20])
values
# Out:
# 0    23.0
# 1    45.0
# 2     NaN
# 3    41.0
# 4    23.0
# 5    34.0
# 6    55.0
# 7     NaN
# 8    34.0
# 9    20.0
# dtype: float64

# %%
# ascending order
values.sort_values(ascending = True)
# Out:
# 9    20.0
# 0    23.0
# 4    23.0
# 5    34.0
# 8    34.0
# 3    41.0
# 1    45.0
# 6    55.0
# 2     NaN
# 7     NaN
# dtype: float64

# %%
# descending order
values.sort_values(ascending = False)
# Out:
# 6    55.0
# 1    45.0
# 3    41.0
# 5    34.0
# 8    34.0
# 0    23.0
# 4    23.0
# 9    20.0
# 2     NaN
# 7     NaN
# dtype: float64

# %%
# create a pandas series
string_values = pd.Series(["a", "j", "d", "f", "t", "a"])

string_values
# sort categorical
# Out:
# 0    a
# 1    j
# 2    d
# 3    f
# 4    t
# 5    a
# dtype: object

# %%
# ascending order
string_values.sort_values(ascending = True).reset_index()
# Out:
#    index  0
# 0      0  a
# 1      5  a
# 2      2  d
# 3      3  f
# 4      1  j
# 5      4  t

# %%
# descending order
string_values.sort_values(ascending = False)
# Out:
# 4    t
# 1    j
# 3    f
# 2    d
# 0    a
# 5    a
# dtype: object

# %% [markdown]
# <a id="dataframes"> </a>
# ## 4. Pandas Dataframes
# #### Introduction to Dataframes and Creating Dataframes

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> A Dataframe is a tabular representation of data containing an ordered collection of columns, each of which can be a different type (numeric, string, boolean, and so on). <br><br>
#                         The Dataframe has both a row and column index; it can be thought of as a dict of Series all sharing the same index. In a dataframe, the data is stored as one or more two-dimensional blocks rather than a list, dict, or some other collection of one-dimensional arrays.
# <br><br>
#                         While a Dataframe is physically two-dimensional, it can be used to represent higher dimensional data in a tabular format using hierarchical indexing.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="creatingDF"> </a>
# ### 4.1 Creating Dataframes

# %% [markdown]
# **1. Creating a dataframe a dictionary**

# %%
data = {'Subject': ['Maths', 'History', 'Science', 'English', 'Georaphy', 'Art'],
        'Marks': (45, 65, 78,65, 80, 78),
        'CGPA': [2.5, 3.0, 3.5, 2.0, 4.0, 4.0]}

df = pd.DataFrame(data)
print(df)
# Out:
#     Subject  Marks  CGPA
# 0     Maths     45   2.5
# 1   History     65   3.0
# 2   Science     78   3.5
# 3   English     65   2.0
# 4  Georaphy     80   4.0
# 5       Art     78   4.0

# %% [markdown]
# **Note:** Like Series, the resulting Dataframe is assigned index automatically. The 'Marks' values are in a tuple.

# %% [markdown]
# **2. To create dataframe from series**

# %%
Subject = pd.Series(['Maths', 'History', 'Science', 'English', 'Georaphy', 'Art'])
Marks = pd.Series([45, 65, 78, 65, 80, 78])
CGPA = pd.Series([2.5, 3.0, 3.5, 2.0, 4.0, 4.0])

# %%
pd.DataFrame([Subject,Marks,CGPA],index=['Subject','Marks','CGPA']).T
# Out:
#     Subject Marks CGPA
# 0     Maths    45  2.5
# 1   History    65  3.0
# 2   Science    78  3.5
# 3   English    65  2.0
# 4  Georaphy    80  4.0
# 5       Art    78  4.0

# %% [markdown]
# **3. To create dataframe from lists**

# %%
Subject = ['Maths', 'History', 'Science', 'English', 'Georaphy', 'Art']
Marks = [45, 65, 78, 65, 80, 78]
CGPA = [2.5, 3.0, 3.5, 2.0, 4.0, 4.0]

# %%
d=pd.DataFrame([Subject,Marks,CGPA], index = ['Subject','Marks','CGPA']).T
d
# Out:
#     Subject Marks CGPA
# 0     Maths    45  2.5
# 1   History    65  3.0
# 2   Science    78  3.5
# 3   English    65  2.0
# 4  Georaphy    80  4.0
# 5       Art    78  4.0

# %%
print(d[['CGPA','Subject']])
# Out:
#   CGPA   Subject
# 0  2.5     Maths
# 1  3.0   History
# 2  3.5   Science
# 3  2.0   English
# 4  4.0  Georaphy
# 5  4.0       Art

# %% [markdown]
# ### To read data from csv file**

# %%
data = pd.read_csv("Data.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data = pd.read_csv("Data.csv")
#       2 data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data.csv'

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#print(data)

# %%
data.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#head()
#tail()
#data.shape
#print(data.info())
#data.describe(object==True)
data.Country.unique()
#data.Country.nunique()
#type(data.Age)
#type(data['Age'])
#data.sort_value('Age')
#data.Country.unique()
#data["Age","Country"]
#data.Age.sum()#,.min(),.max(),.values(),.value_counts()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %% [markdown]
# <a id="manipulatingDF"> </a>
# ### 4.2  Manipulating Dataframes
# #### Manipulating the Dataframes

# %% [markdown]
# ### Add new column and rows

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> CAUTION:<br>
#                         1. DataFrame[column] works for any column name, but DataFrame.column only works when the column name is a valid Python variable name.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Adding a new column to the data set**

# %%
data["New"] = data["Age"] / data["Salary"]

# %%
data
# Out:
#    Country   Age   Salary Purchased       New
# 0   France  44.0  72000.0        No  0.000611
# 1    Spain  27.0  48000.0       Yes  0.000562
# 2  Germany  30.0  54000.0        No  0.000556
# 3    Spain  38.0  61000.0        No  0.000623
# 4  Germany  40.0      NaN       Yes       NaN
# 5   France  35.0  58000.0       Yes  0.000603
# 6    Spain   NaN  52000.0        No       NaN
# 7   France  48.0  79000.0       Yes  0.000608
# 8  Germany  50.0  83000.0        No  0.000602
# 9   France  37.0  67000.0       Yes  0.000552

# %%
data['C']=[i for i in range(0,10)]
data
# Out:
#    Country   Age   Salary Purchased  C
# 0   France  44.0  72000.0        No  0
# 1    Spain  27.0  48000.0       Yes  1
# 2  Germany  30.0  54000.0        No  2
# 3    Spain  38.0  61000.0        No  3
# 4  Germany  40.0      NaN       Yes  4
# 5   France  35.0  58000.0       Yes  5
# 6    Spain   NaN  52000.0        No  6
# 7   France  48.0  79000.0       Yes  7
# 8  Germany  50.0  83000.0        No  8
# 9   France  37.0  67000.0       Yes  9

# %%
# Insert column 'D' at position 1
data.insert(1, 'D', [i for i in range(10,20)])
data
# Out:
#    Country   D   Age   Salary Purchased  C
# 0   France  10  44.0  72000.0        No  0
# 1    Spain  11  27.0  48000.0       Yes  1
# 2  Germany  12  30.0  54000.0        No  2
# 3    Spain  13  38.0  61000.0        No  3
# 4  Germany  14  40.0      NaN       Yes  4
# 5   France  15  35.0  58000.0       Yes  5
# 6    Spain  16   NaN  52000.0        No  6
# 7   France  17  48.0  79000.0       Yes  7
# 8  Germany  18  50.0  83000.0        No  8
# 9   France  19  37.0  67000.0       Yes  9

# %%
data['C']=100

# %%
data
# Out:
#    Country   D   Age   Salary Purchased    C
# 0   France  10  44.0  72000.0        No  100
# 1    Spain  11  27.0  48000.0       Yes  100
# 2  Germany  12  30.0  54000.0        No  100
# 3    Spain  13  38.0  61000.0        No  100
# 4  Germany  14  40.0      NaN       Yes  100
# 5   France  15  35.0  58000.0       Yes  100
# 6    Spain  16   NaN  52000.0        No  100
# 7   France  17  48.0  79000.0       Yes  100
# 8  Germany  18  50.0  83000.0        No  100
# 9   France  19  37.0  67000.0       Yes  100

# %% [markdown]
# **Adding a new row to the data set**

# %% [markdown]
# A new row can be added using the function copy()

# %%
data_copy = data.copy()
data_copy.loc[10] = [45, 85, 1.8, 26.3,23.7,44]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data_copy = data.copy()
#       2 data_copy.loc[10] = [45, 85, 1.8, 26.3,23.7,44]
#
# NameError: name 'data' is not defined

# %%
data
# Out:
#    Country   D   Age   Salary Purchased    C
# 0   France  10  44.0  72000.0        No  100
# 1    Spain  11  27.0  48000.0       Yes  100
# 2  Germany  12  30.0  54000.0        No  100
# 3    Spain  13  38.0  61000.0        No  100
# 4  Germany  14  40.0      NaN       Yes  100
# 5   France  15  35.0  58000.0       Yes  100
# 6    Spain  16   NaN  52000.0        No  100
# 7   France  17  48.0  79000.0       Yes  100
# 8  Germany  18  50.0  83000.0        No  100
# 9   France  19  37.0  67000.0       Yes  100

# %%
data_copy
# Out:
#     Country     D   Age   Salary Purchased      C
# 0    France  10.0  44.0  72000.0        No  100.0
# 1     Spain  11.0  27.0  48000.0       Yes  100.0
# 2   Germany  12.0  30.0  54000.0        No  100.0
# 3     Spain  13.0  38.0  61000.0        No  100.0
# 4   Germany  14.0  40.0      NaN       Yes  100.0
# 5    France  15.0  35.0  58000.0       Yes  100.0
# 6     Spain  16.0   NaN  52000.0        No  100.0
# 7    France  17.0  48.0  79000.0       Yes  100.0
# 8   Germany  18.0  50.0  83000.0        No  100.0
# 9    France  19.0  37.0  67000.0       Yes  100.0
# 10     45.0  85.0   1.8     26.3      23.7   44.0

# %% [markdown]
# ### Selecting columns

# %% [markdown]
# **Indexing a dataframe using `.iloc`**
#
# `DataFrame.iloc[]`

# %%
# Select 2nd row
data.iloc[2]
# Out:
# Country      Germany
# D                 12
# Age             30.0
# Salary       54000.0
# Purchased         No
# C                100
# Name: 2, dtype: object

# %%
# select multiple rows
data.iloc[[4,7,9]]
# Out:
#    Country   D   Age   Salary Purchased    C
# 4  Germany  14  40.0      NaN       Yes  100
# 7   France  17  48.0  79000.0       Yes  100
# 9   France  19  37.0  67000.0       Yes  100

# %% [markdown]
# We use two square brackets since we are passing a list of row numbers to be accessed.

# %%
# select 5th to 8th row
data.iloc[5:9]
# Out:
#    Country   D   Age   Salary Purchased    C
# 5   France  15  35.0  58000.0       Yes  100
# 6    Spain  16   NaN  52000.0        No  100
# 7   France  17  48.0  79000.0       Yes  100
# 8  Germany  18  50.0  83000.0        No  100

# %%
#select column
data.iloc[:, ]#,0,1,-1
# Out:
#    Country   D   Age   Salary Purchased    C
# 0   France  10  44.0  72000.0        No  100
# 1    Spain  11  27.0  48000.0       Yes  100
# 2  Germany  12  30.0  54000.0        No  100
# 3    Spain  13  38.0  61000.0        No  100
# 4  Germany  14  40.0      NaN       Yes  100
# 5   France  15  35.0  58000.0       Yes  100
# 6    Spain  16   NaN  52000.0        No  100
# 7   France  17  48.0  79000.0       Yes  100
# 8  Germany  18  50.0  83000.0        No  100
# 9   France  19  37.0  67000.0       Yes  100

# %% [markdown]
# **Indexing a dataframe using `.loc`**
#
# `DataFrame.loc[]` method is a method that takes only index labels and returns row or dataframe if the index label exists in the caller dataframe. <br>
# `DataFrame.loc[Row_names, column_names]` is used to select or index rows or columns based on their name.

# %% [markdown]
# #### Select 1 to 5 rows and 2nd and 4th columns

# %%
data.loc[0:5,["Age","Salary"]]
# Out:
#     Age   Salary
# 0  44.0  72000.0
# 1  27.0  48000.0
# 2  30.0  54000.0
# 3  38.0  61000.0
# 4  40.0      NaN
# 5  35.0  58000.0

# %% [markdown]
# ### To check for missing values**

# %%
data.isnull()#.sum()
# Out:
#    Country      D    Age  Salary  Purchased      C
# 0    False  False  False   False      False  False
# 1    False  False  False   False      False  False
# 2    False  False  False   False      False  False
# 3    False  False  False   False      False  False
# 4    False  False  False    True      False  False
# 5    False  False  False   False      False  False
# 6    False  False   True   False      False  False
# 7    False  False  False   False      False  False
# 8    False  False  False   False      False  False
# 9    False  False  False   False      False  False

# %%
#data.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data.dropna(axis=1)
#
# NameError: name 'data' is not defined

# %%
#data.fillna({"Age":5,"Salary":0})

# %%
#df.fillna(method="ffill",axis=0)

# %%
#df.fillna(0)

# %%
#df.dropna(how="all")

# %%
data
# Out:
#    Country   D   Age   Salary Purchased    C
# 0   France  10  44.0  72000.0        No  100
# 1    Spain  11  27.0  48000.0       Yes  100
# 2  Germany  12  30.0  54000.0        No  100
# 3    Spain  13  38.0  61000.0        No  100
# 4  Germany  14  40.0      NaN       Yes  100
# 5   France  15  35.0  58000.0       Yes  100
# 6    Spain  16   NaN  52000.0        No  100
# 7   France  17  48.0  79000.0       Yes  100
# 8  Germany  18  50.0  83000.0        No  100
# 9   France  19  37.0  67000.0       Yes  100

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data
# Out:
#    Country   D        Age   Salary Purchased    C
# 0   France  10  44.000000  72000.0        No  100
# 1    Spain  11  27.000000  48000.0       Yes  100
# 2  Germany  12  30.000000  54000.0        No  100
# 3    Spain  13  38.000000  61000.0        No  100
# 4  Germany  14  40.000000      NaN       Yes  100
# 5   France  15  35.000000  58000.0       Yes  100
# 6    Spain  16  38.777778  52000.0        No  100
# 7   France  17  48.000000  79000.0       Yes  100
# 8  Germany  18  50.000000  83000.0        No  100
# 9   France  19  37.000000  67000.0       Yes  100

# %% [markdown]
# ### Delete rows and columns

# %%
# Delete column 'B'
df=data.drop(columns=['D','C'])
df
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0        No
# 1    Spain  27.000000  48000.0       Yes
# 2  Germany  30.000000  54000.0        No
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5   France  35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No
# 9   France  37.000000  67000.0       Yes

# %% [markdown]
# #### delete row

# %%
# Delete row with index 1
df = df.drop(index=9)
df
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0        No
# 1    Spain  27.000000  48000.0       Yes
# 2  Germany  30.000000  54000.0        No
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5   France  35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No

# %% [markdown]
# #### Update rows

# %%
df.loc[1] = [100, 200, 300,444]  # Update row with index 1
df
# Out:
#    Country         Age   Salary Purchased
# 0   France   44.000000  72000.0        No
# 1      100  200.000000    300.0       444
# 2  Germany   30.000000  54000.0        No
# 3    Spain   38.000000  61000.0        No
# 4  Germany   40.000000      NaN       Yes
# 5   France   35.000000  58000.0       Yes
# 6    Spain   38.777778  52000.0        No
# 7   France   48.000000  79000.0       Yes
# 8  Germany   50.000000  83000.0        No

# %%
df['Country'] = df['Country'].replace(100, 'Pakistan')  # Replace all 2s with 999 in column 'A'
df
# Out:
#     Country         Age   Salary Purchased
# 0    France   44.000000  72000.0        No
# 1  Pakistan  200.000000    300.0       444
# 2   Germany   30.000000  54000.0        No
# 3     Spain   38.000000  61000.0        No
# 4   Germany   40.000000      NaN       Yes
# 5    France   35.000000  58000.0       Yes
# 6     Spain   38.777778  52000.0        No
# 7    France   48.000000  79000.0       Yes
# 8   Germany   50.000000  83000.0        No

# %%
df.iat[1, 2] = 399  # Update row 0 (first row), column 1 (second column)
df
# Out:
#     Country         Age   Salary Purchased
# 0    France   44.000000  72000.0        No
# 1  Pakistan  200.000000    399.0       444
# 2   Germany   30.000000  54000.0        No
# 3     Spain   38.000000  61000.0        No
# 4   Germany   40.000000      NaN       Yes
# 5    France   35.000000  58000.0       Yes
# 6     Spain   38.777778  52000.0        No
# 7    France   48.000000  79000.0       Yes
# 8   Germany   50.000000  83000.0        No

# %% [markdown]
# Note:
#
# .drop() returns a new DataFrame unless you use inplace=True.
# To reset the index after deleting rows, use

# %%
#### Drop duplicated data

# %%
# Create a DataFrame
d = {
    'Name':['Alisa','Bobby','jodha','jack','raghu','Cathrine',
            'Alisa','Bobby','kumar','Alisa','Alex','Cathrine'],
    'Company':['Apple','Walmart','Walmart','Intel','Apple','Walmart','Apple','Cognizant','Apple','Apple','Cognizant','Walmart'],
      
       'Salary':[8500,6300,5500,7400,3100,7700,8500,6300,4200,6200,8900,7700]}
 
df = pd.DataFrame(d,columns=['Name','Company','Salary'])
df
# Out:
#         Name    Company  Salary
# 0      Alisa      Apple    8500
# 1      Bobby    Walmart    6300
# 2      jodha    Walmart    5500
# 3       jack      Intel    7400
# 4      raghu      Apple    3100
# 5   Cathrine    Walmart    7700
# 6      Alisa      Apple    8500
# 7      Bobby  Cognizant    6300
# 8      kumar      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900
# 11  Cathrine    Walmart    7700

# %% [markdown]
# **duplicate rows based on all columns**

# %%
# Select duplicate rows except first occurrence based on all columns
duplicate_df = df[df.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicate_df)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#         Name  Company  Salary
# 6      Alisa    Apple    8500
# 11  Cathrine  Walmart    7700

# %% [markdown]
# **Duplicate Rows Based on Selected Columns**

# %% [markdown]
# Let’s find & select rows based on a single column.

# %%
duplicate_df_ = df[df.duplicated('Name')]
print(duplicate_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 duplicate_df_name = df[df.duplicated('Name')]
#       2 print(duplicate_df_name)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Find & select rows based on a two column names.

# %%
duplicate_df = df[df.duplicated(['Name', 'Company'])]
print(duplicate_df)
# Out:
#         Name  Company  Salary
# 6      Alisa    Apple    8500
# 9      Alisa    Apple    6200
# 11  Cathrine  Walmart    7700

# %% [markdown]
# **Dropping the Duplicate Rows**

# %%
df.drop_duplicates()
# Out:
#         Name    Company  Salary
# 0      Alisa      Apple    8500
# 1      Bobby    Walmart    6300
# 2      jodha    Walmart    5500
# 3       jack      Intel    7400
# 4      raghu      Apple    3100
# 5   Cathrine    Walmart    7700
# 7      Bobby  Cognizant    6300
# 8      kumar      Apple    4200
# 9      Alisa      Apple    6200
# 10      Alex  Cognizant    8900

# %%
#data.to_csv("new_data.csv")

# %% [markdown]
# #### .apply()

# %%
import pandas as pd
# Sample DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})
# Apply a function to double the values in column 'A'
df['A'] = df['A'].apply(lambda x: x * 2)
print(df)
# Out:
#    A  B
# 0  2  4
# 1  4  5
# 2  6  6

# %% [markdown]
# <a id="Merging"> </a>
# ### 5. Merging
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>"Merging" two datasets is the process of bringing two datasets together into one, and aligning the rows from each based on common attributes or columns.<br>
#                     This is achieved by the parameter “on” which allow us to select the common column between two dataframes.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Concatenate using `.merge()`

# %%
my_df1=pd.DataFrame({
 'Product_ID':[101,102,103,104,105,106],
 'Food_Product':['Cakes','Biscuits','Fruit','Beverages','Cakes','Beverages'],
 'Brand':['Baskin Robbins','Blue Riband','Peach','Horlicks','Mars Muffin','Mirinda'], 
})
print("The first dataframe is : \n",my_df1,"\n\n")

my_df2=pd.DataFrame({
 'Product_ID':[104,102,101,103,107,108],
 'Food_Product':['Beverages', 'Biscuits', 'Cakes', 'Fruit', 'Breakfast foods', 'Chips'],
  'Brand':['Coca-Cola', 'Oreo', 'Dunkin Donuts', 'Banana', 'Cream of Wheat', 'Cheetos']  
})
print("The second dataframe is : \n",my_df2)
# Out:
# The first dataframe is :
#     Product_ID Food_Product           Brand
# 0         101        Cakes  Baskin Robbins
# 1         102     Biscuits     Blue Riband
# 2         103        Fruit           Peach
# 3         104    Beverages        Horlicks
# 4         105        Cakes     Mars Muffin
# 5         106    Beverages         Mirinda
#
#
# The second dataframe is :
#     Product_ID     Food_Product           Brand
# 0         104        Beverages       Coca-Cola
# 1         102         Biscuits            Oreo
# 2         101            Cakes   Dunkin Donuts
# 3         103            Fruit          Banana
# 4         107  Breakfast foods  Cream of Wheat
# 5         108            Chips         Cheetos

# %%
pd.merge(my_df1, my_df2, on='Product_ID')
# Out:
#    Product_ID Food_Product_x         Brand_x Food_Product_y        Brand_y
# 0         101          Cakes  Baskin Robbins          Cakes  Dunkin Donuts
# 1         102       Biscuits     Blue Riband       Biscuits           Oreo
# 2         103          Fruit           Peach          Fruit         Banana
# 3         104      Beverages        Horlicks      Beverages      Coca-Cola

# %% [markdown]
# #### merging using multiple keys

# %%
 pd.merge(my_df1, my_df2, on=['Product_ID','Food_Product'])
# Out:
#    Product_ID Food_Product         Brand_x        Brand_y
# 0         101        Cakes  Baskin Robbins  Dunkin Donuts
# 1         102     Biscuits     Blue Riband           Oreo
# 2         103        Fruit           Peach         Banana
# 3         104    Beverages        Horlicks      Coca-Cola

# %% [markdown]
# <a id="Groupby"> </a>
# ### 6. Groupby in Pandas

# %%
# create a dataframe
my_df1=pd.DataFrame({
 'Product_ID':[101,102,103,104,105,106],
 'Food_Product':['Cakes','Biscuits','Fruit','Beverages','Cakes','Beverages'],
 'Brand':['Baskin Robbins','Blue Riband','Peach','Horlicks','Mars Muffin','Mirinda'],
 'Sales': [5000, 8000, 7600, 5500, 6500, 9000],
 'Profit': [55000, 67000, 89000, 78000, 55000, 90000]   
})
print(my_df1)
# Out:
#    Product_ID Food_Product           Brand  Sales  Profit
# 0         101        Cakes  Baskin Robbins   5000   55000
# 1         102     Biscuits     Blue Riband   8000   67000
# 2         103        Fruit           Peach   7600   89000
# 3         104    Beverages        Horlicks   5500   78000
# 4         105        Cakes     Mars Muffin   6500   55000
# 5         106    Beverages         Mirinda   9000   90000

# %%
my_df1
# Out:
#    Product_ID Food_Product           Brand  Sales  Profit
# 0         101        Cakes  Baskin Robbins   5000   55000
# 1         102     Biscuits     Blue Riband   8000   67000
# 2         103        Fruit           Peach   7600   89000
# 3         104    Beverages        Horlicks   5500   78000
# 4         105        Cakes     Mars Muffin   6500   55000
# 5         106    Beverages         Mirinda   9000   90000

# %% [markdown]
# **Number of Unique Column Values Per Group**

# %%
my_df1.groupby("Food_Product")["Sales"].nunique().to_frame()
# Out:
#               Sales
# Food_Product
# Beverages         2
# Biscuits          1
# Cakes             2
# Fruit             1

# %% [markdown]
# **Sort Groupby Results**

# %% [markdown]
# Turn the groupby object into a regular dataframe by calling `.to_frame()` and then re-index with `reset_index()`, then you can also call sort_values() as you would do for a normal dataframe.

# %%
my_df1.groupby('Food_Product')['Sales'].sum().to_frame().reset_index()
# Out:
#   Food_Product  Sales
# 0    Beverages  14500
# 1     Biscuits   8000
# 2        Cakes  11500
# 3        Fruit   7600

# %%
my_df1.groupby('Food_Product')['Sales'].sum().to_frame().reset_index().sort_values(by='Sales')
# Out:
#   Food_Product  Sales
# 3        Fruit   7600
# 1     Biscuits   8000
# 2        Cakes  11500
# 0    Beverages  14500

# %% [markdown]
# **Hierarchical Indices Created by Groupby**

# %%
my_df1.groupby('Food_Product').agg({'Sales':['min','max','mean']})
# Out:
#              Sales
#                min   max    mean
# Food_Product
# Beverages     5500  9000  7250.0
# Biscuits      8000  8000  8000.0
# Cakes         5000  6500  5750.0
# Fruit         7600  7600  7600.0

# %%
#flatten 
result = my_df1.groupby('Food_Product').agg({'Sales': ['min', 'max', 'mean']}).reset_index()
result.columns = ['Food_Product', 'Min_Sales', 'Max_Sales', 'Mean_Sales']
print(result)
# Out:
#   Food_Product  Min_Sales  Max_Sales  Mean_Sales
# 0    Beverages       5500       9000      7250.0
# 1     Biscuits       8000       8000      8000.0
# 2        Cakes       5000       6500      5750.0
# 3        Fruit       7600       7600      7600.0

# %%
result = my_df1.groupby('Food_Product').agg(
    Min_Sales=('Sales', 'min'),
    Max_Sales=('Sales', 'max'),
    Avg_Sales=('Sales', 'mean')
).reset_index()

# %%
result
# Out:
#   Food_Product  Min_Sales  Max_Sales  Avg_Sales
# 0    Beverages       5500       9000     7250.0
# 1     Biscuits       8000       8000     8000.0
# 2        Cakes       5000       6500     5750.0
# 3        Fruit       7600       7600     7600.0
